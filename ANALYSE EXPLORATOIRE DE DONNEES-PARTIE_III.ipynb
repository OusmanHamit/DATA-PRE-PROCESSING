# %%
import pandas as pd

# %%
pd.__version__
# Out:
# '1.4.1'

# %%
# pd.set_option('display.max_rows', None)
# pd.set_option('display.max_columns', None)

# %%
df = pd.read_csv('supermarket_sales - Sheet1.csv')

# %%
df
# Out:
#       Invoice ID Branch       City Customer type  Gender  \
# 0    750-67-8428      A     Yangon        Member  Female
# 1    226-31-3081      C  Naypyitaw        Normal  Female
# 2    631-41-3108      A     Yangon        Normal    Male
# 3    123-19-1176      A     Yangon        Member    Male
# 4    373-73-7910      A     Yangon        Normal    Male
# ..           ...    ...        ...           ...     ...
# 995  233-67-5758      C  Naypyitaw        Normal    Male
# 996  303-96-2227      B   Mandalay        Normal  Female
# 997  727-02-1313      A     Yangon        Member    Male
# 998  347-56-2442      A     Yangon        Normal    Male
# 999  849-09-3807      A     Yangon        Member  Female
#
#                Product line  Unit price  Quantity   Tax 5%      Total  \
# 0         Health and beauty       74.69         7  26.1415   548.9715
# 1    Electronic accessories       15.28         5   3.8200    80.2200
# ...

# %%
df.head()
# Out:
#     Invoice ID Branch       City Customer type  Gender  \
# 0  750-67-8428      A     Yangon        Member  Female
# 1  226-31-3081      C  Naypyitaw        Normal  Female
# 2  631-41-3108      A     Yangon        Normal    Male
# 3  123-19-1176      A     Yangon        Member    Male
# 4  373-73-7910      A     Yangon        Normal    Male
#
#              Product line  Unit price  Quantity   Tax 5%     Total       Date  \
# 0       Health and beauty       74.69         7  26.1415  548.9715   1/5/2019
# 1  Electronic accessories       15.28         5   3.8200   80.2200   3/8/2019
# 2      Home and lifestyle       46.33         7  16.2155  340.5255   3/3/2019
# 3       Health and beauty       58.22         8  23.2880  489.0480  1/27/2019
# 4       Sports and travel       86.31         7  30.2085  634.3785   2/8/2019
#
#     Time      Payment    cogs  gross margin percentage  gross income  Rating
# 0  13:08      Ewallet  522.83                 4.761905       26.1415     9.1
# ...

# %%
df.tail()
# Out:
#       Invoice ID Branch       City Customer type  Gender         Product line  \
# 995  233-67-5758      C  Naypyitaw        Normal    Male    Health and beauty
# 996  303-96-2227      B   Mandalay        Normal  Female   Home and lifestyle
# 997  727-02-1313      A     Yangon        Member    Male   Food and beverages
# 998  347-56-2442      A     Yangon        Normal    Male   Home and lifestyle
# 999  849-09-3807      A     Yangon        Member  Female  Fashion accessories
#
#      Unit price  Quantity   Tax 5%      Total       Date   Time  Payment  \
# 995       40.35         1   2.0175    42.3675  1/29/2019  13:46  Ewallet
# 996       97.38        10  48.6900  1022.4900   3/2/2019  17:16  Ewallet
# 997       31.84         1   1.5920    33.4320   2/9/2019  13:22     Cash
# 998       65.82         1   3.2910    69.1110  2/22/2019  15:33     Cash
# 999       88.34         7  30.9190   649.2990  2/18/2019  13:28     Cash
#
# ...

# %%
df.dtypes
# Out:
# Invoice ID                  object
# Branch                      object
# City                        object
# Customer type               object
# Gender                      object
# Product line                object
# Unit price                 float64
# Quantity                     int64
# Tax 5%                     float64
# Total                      float64
# Date                        object
# Time                        object
# Payment                     object
# cogs                       float64
# gross margin percentage    float64
# gross income               float64
# Rating                     float64
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 17 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Invoice ID               1000 non-null   object
#  1   Branch                   1000 non-null   object
#  2   City                     1000 non-null   object
#  3   Customer type            1000 non-null   object
#  4   Gender                   1000 non-null   object
#  5   Product line             1000 non-null   object
#  6   Unit price               1000 non-null   float64
#  7   Quantity                 1000 non-null   int64
#  8   Tax 5%                   1000 non-null   float64
#  9   Total                    1000 non-null   float64
#  10  Date                     1000 non-null   object
#  11  Time                     1000 non-null   object
#  12  Payment                  1000 non-null   object
#  13  cogs                     1000 non-null   float64
# ...

# %%
for colname in df: 
    print(colname)
# Out:
# Invoice ID
# Branch
# City
# Customer type
# Gender
# Product line
# Unit price
# Quantity
# Tax 5%
# Total
# Date
# Time
# Payment
# cogs
# gross margin percentage
# gross income
# Rating

# %%
df.shape
# Out:
# (1000, 17)

# %%
df.shape[0]
# Out:
# 1000

# %%
df.shape[1]
# Out:
# 17

# %%
df.dtypes.value_counts()
# Out:
# object     9
# float64    7
# int64      1
# dtype: int64

# %%
df.select_dtypes(['object']).head()
# Out:
#     Invoice ID Branch       City Customer type  Gender  \
# 0  750-67-8428      A     Yangon        Member  Female
# 1  226-31-3081      C  Naypyitaw        Normal  Female
# 2  631-41-3108      A     Yangon        Normal    Male
# 3  123-19-1176      A     Yangon        Member    Male
# 4  373-73-7910      A     Yangon        Normal    Male
#
#              Product line       Date   Time      Payment
# 0       Health and beauty   1/5/2019  13:08      Ewallet
# 1  Electronic accessories   3/8/2019  10:29         Cash
# 2      Home and lifestyle   3/3/2019  13:23  Credit card
# 3       Health and beauty  1/27/2019  20:33      Ewallet
# 4       Sports and travel   2/8/2019  10:37      Ewallet

# %%
df.select_dtypes(['number']).head()
# Out:
#    Unit price  Quantity   Tax 5%     Total    cogs  gross margin percentage  \
# 0       74.69         7  26.1415  548.9715  522.83                 4.761905
# 1       15.28         5   3.8200   80.2200   76.40                 4.761905
# 2       46.33         7  16.2155  340.5255  324.31                 4.761905
# 3       58.22         8  23.2880  489.0480  465.76                 4.761905
# 4       86.31         7  30.2085  634.3785  604.17                 4.761905
#
#    gross income  Rating
# 0       26.1415     9.1
# 1        3.8200     9.6
# 2       16.2155     7.4
# 3       23.2880     8.4
# 4       30.2085     5.3

# %%
df['Unit price'].unique()
# Out:
# array([74.69, 15.28, 46.33, 58.22, 86.31, 85.39, 68.84, 73.56, 36.26,
#        54.84, 14.48, 25.51, 46.95, 43.19, 71.38, 93.72, 68.93, 72.61,
#        54.67, 40.3 , 86.04, 87.98, 33.2 , 34.56, 88.63, 52.59, 33.52,
#        87.67, 88.36, 24.89, 94.13, 78.07, 83.78, 96.58, 99.42, 68.12,
#        62.62, 60.88, 54.92, 30.12, 86.72, 56.11, 69.12, 98.7 , 15.37,
#        93.96, 56.69, 20.01, 18.93, 82.63, 91.4 , 44.59, 17.87, 15.43,
#        16.16, 85.98, 44.34, 89.6 , 72.35, 30.61, 24.74, 55.73, 55.07,
#        15.81, 75.74, 15.87, 33.47, 97.61, 78.77, 18.33, 89.48, 62.12,
#        48.52, 75.91, 74.67, 41.65, 49.04, 78.31, 20.38, 99.19, 96.68,
#        19.25, 80.36, 48.91, 83.06, 76.52, 49.38, 42.47, 76.99, 47.38,
#        44.86, 21.98, 64.36, 89.75, 97.16, 87.87, 12.45, 52.75, 82.7 ,
#        48.71, 78.55, 23.07, 58.26, 30.35, 88.67, 27.38, 62.13, 33.98,
#        81.97, 16.49, 98.21, 72.84, 58.07, 80.79, 27.02, 21.94, 51.36,
# ...

# %%
df['Unit price'].nunique()
# Out:
# 943

# %%
df['Payment'].unique()
# Out:
# array(['Ewallet', 'Cash', 'Credit card'], dtype=object)

# %%
df['Payment'].nunique()
# Out:
# 3

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 17 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Invoice ID               1000 non-null   object
#  1   Branch                   1000 non-null   object
#  2   City                     1000 non-null   object
#  3   Customer type            1000 non-null   object
#  4   Gender                   1000 non-null   object
#  5   Product line             1000 non-null   object
#  6   Unit price               1000 non-null   float64
#  7   Quantity                 1000 non-null   int64
#  8   Tax 5%                   1000 non-null   float64
#  9   Total                    1000 non-null   float64
#  10  Date                     1000 non-null   object
#  11  Time                     1000 non-null   object
#  12  Payment                  1000 non-null   object
#  13  cogs                     1000 non-null   float64
# ...

# %%
df.select_dtypes(['number']).head()
# Out:
#    Unit price  Quantity   Tax 5%     Total    cogs  gross margin percentage  \
# 0       74.69         7  26.1415  548.9715  522.83                 4.761905
# 1       15.28         5   3.8200   80.2200   76.40                 4.761905
# 2       46.33         7  16.2155  340.5255  324.31                 4.761905
# 3       58.22         8  23.2880  489.0480  465.76                 4.761905
# 4       86.31         7  30.2085  634.3785  604.17                 4.761905
#
#    gross income  Rating
# 0       26.1415     9.1
# 1        3.8200     9.6
# 2       16.2155     7.4
# 3       23.2880     8.4
# 4       30.2085     5.3

# %%
df['Quantity'].astype(float)
# Out:
# 0       7.0
# 1       5.0
# 2       7.0
# 3       8.0
# 4       7.0
#        ...
# 995     1.0
# 996    10.0
# 997     1.0
# 998     1.0
# 999     7.0
# Name: Quantity, Length: 1000, dtype: float64

# %%
df.isna().sum()
# Out:
# Invoice ID                 0
# Branch                     0
# City                       0
# Customer type              0
# Gender                     0
# Product line               0
# Unit price                 0
# Quantity                   0
# Tax 5%                     0
# Total                      0
# Date                       0
# Time                       0
# Payment                    0
# cogs                       0
# gross margin percentage    0
# gross income               0
# Rating                     0
# dtype: int64

# %%
df.isna().sum().sum()
# Out:
# 0

# %%
df.describe()
# Out:
#         Unit price     Quantity       Tax 5%        Total        cogs  \
# count  1000.000000  1000.000000  1000.000000  1000.000000  1000.00000
# mean     55.672130     5.510000    15.379369   322.966749   307.58738
# std      26.494628     2.923431    11.708825   245.885335   234.17651
# min      10.080000     1.000000     0.508500    10.678500    10.17000
# 25%      32.875000     3.000000     5.924875   124.422375   118.49750
# 50%      55.230000     5.000000    12.088000   253.848000   241.76000
# 75%      77.935000     8.000000    22.445250   471.350250   448.90500
# max      99.960000    10.000000    49.650000  1042.650000   993.00000
#
#        gross margin percentage  gross income      Rating
# count              1000.000000   1000.000000  1000.00000
# mean                  4.761905     15.379369     6.97270
# std                   0.000000     11.708825     1.71858
# min                   4.761905      0.508500     4.00000
# ...

# %%
df.head()
# Out:
#     Invoice ID Branch       City Customer type  Gender  \
# 0  750-67-8428      A     Yangon        Member  Female
# 1  226-31-3081      C  Naypyitaw        Normal  Female
# 2  631-41-3108      A     Yangon        Normal    Male
# 3  123-19-1176      A     Yangon        Member    Male
# 4  373-73-7910      A     Yangon        Normal    Male
#
#              Product line  Unit price  Quantity   Tax 5%     Total       Date  \
# 0       Health and beauty       74.69         7  26.1415  548.9715   1/5/2019
# 1  Electronic accessories       15.28         5   3.8200   80.2200   3/8/2019
# 2      Home and lifestyle       46.33         7  16.2155  340.5255   3/3/2019
# 3       Health and beauty       58.22         8  23.2880  489.0480  1/27/2019
# 4       Sports and travel       86.31         7  30.2085  634.3785   2/8/2019
#
#     Time      Payment    cogs  gross margin percentage  gross income  Rating
# 0  13:08      Ewallet  522.83                 4.761905       26.1415     9.1
# ...

# %%
def lowerCase(df):
    df.columns = [colname.lower() for colname in df.columns]

# %%
lowerCase(df)

# %%
df.head()
# Out:
#     invoice id branch       city customer type  gender  \
# 0  750-67-8428      A     Yangon        Member  Female
# 1  226-31-3081      C  Naypyitaw        Normal  Female
# 2  631-41-3108      A     Yangon        Normal    Male
# 3  123-19-1176      A     Yangon        Member    Male
# 4  373-73-7910      A     Yangon        Normal    Male
#
#              product line  unit price  quantity   tax 5%     total       date  \
# 0       Health and beauty       74.69         7  26.1415  548.9715   1/5/2019
# 1  Electronic accessories       15.28         5   3.8200   80.2200   3/8/2019
# 2      Home and lifestyle       46.33         7  16.2155  340.5255   3/3/2019
# 3       Health and beauty       58.22         8  23.2880  489.0480  1/27/2019
# 4       Sports and travel       86.31         7  30.2085  634.3785   2/8/2019
#
#     time      payment    cogs  gross margin percentage  gross income  rating
# 0  13:08      Ewallet  522.83                 4.761905       26.1415     9.1
# ...

# %%
def upperCase(df):
    df.columns = [colname.upper() for colname in df.columns]

# %%
upperCase(df)

# %%
df.head()
# Out:
#     INVOICE ID BRANCH       CITY CUSTOMER TYPE  GENDER  \
# 0  750-67-8428      A     Yangon        Member  Female
# 1  226-31-3081      C  Naypyitaw        Normal  Female
# 2  631-41-3108      A     Yangon        Normal    Male
# 3  123-19-1176      A     Yangon        Member    Male
# 4  373-73-7910      A     Yangon        Normal    Male
#
#              PRODUCT LINE  UNIT PRICE  QUANTITY   TAX 5%     TOTAL       DATE  \
# 0       Health and beauty       74.69         7  26.1415  548.9715   1/5/2019
# 1  Electronic accessories       15.28         5   3.8200   80.2200   3/8/2019
# 2      Home and lifestyle       46.33         7  16.2155  340.5255   3/3/2019
# 3       Health and beauty       58.22         8  23.2880  489.0480  1/27/2019
# 4       Sports and travel       86.31         7  30.2085  634.3785   2/8/2019
#
#     TIME      PAYMENT    COGS  GROSS MARGIN PERCENTAGE  GROSS INCOME  RATING
# 0  13:08      Ewallet  522.83                 4.761905       26.1415     9.1
# ...

# %%
def lowerCaseContent(df):
    for colname in df.select_dtypes(['object']):        
        df[colname] = df[colname].str.lower()

# %%
lowerCaseContent(df)

# %%
df.head()
# Out:
#     INVOICE ID BRANCH       CITY CUSTOMER TYPE  GENDER  \
# 0  750-67-8428      a     yangon        member  female
# 1  226-31-3081      c  naypyitaw        normal  female
# 2  631-41-3108      a     yangon        normal    male
# 3  123-19-1176      a     yangon        member    male
# 4  373-73-7910      a     yangon        normal    male
#
#              PRODUCT LINE  UNIT PRICE  QUANTITY   TAX 5%     TOTAL       DATE  \
# 0       health and beauty       74.69         7  26.1415  548.9715   1/5/2019
# 1  electronic accessories       15.28         5   3.8200   80.2200   3/8/2019
# 2      home and lifestyle       46.33         7  16.2155  340.5255   3/3/2019
# 3       health and beauty       58.22         8  23.2880  489.0480  1/27/2019
# 4       sports and travel       86.31         7  30.2085  634.3785   2/8/2019
#
#     TIME      PAYMENT    COGS  GROSS MARGIN PERCENTAGE  GROSS INCOME  RATING
# 0  13:08      ewallet  522.83                 4.761905       26.1415     9.1
# ...

# %%
def upperCaseContent(df):
    for colname in df.select_dtypes(['object']):        
        df[colname] = df[colname].str.upper()

# %%
upperCaseContent(df)

# %%
df.head()
# Out:
#     INVOICE ID BRANCH       CITY CUSTOMER TYPE  GENDER  \
# 0  750-67-8428      A     YANGON        MEMBER  FEMALE
# 1  226-31-3081      C  NAYPYITAW        NORMAL  FEMALE
# 2  631-41-3108      A     YANGON        NORMAL    MALE
# 3  123-19-1176      A     YANGON        MEMBER    MALE
# 4  373-73-7910      A     YANGON        NORMAL    MALE
#
#              PRODUCT LINE  UNIT PRICE  QUANTITY   TAX 5%     TOTAL       DATE  \
# 0       HEALTH AND BEAUTY       74.69         7  26.1415  548.9715   1/5/2019
# 1  ELECTRONIC ACCESSORIES       15.28         5   3.8200   80.2200   3/8/2019
# 2      HOME AND LIFESTYLE       46.33         7  16.2155  340.5255   3/3/2019
# 3       HEALTH AND BEAUTY       58.22         8  23.2880  489.0480  1/27/2019
# 4       SPORTS AND TRAVEL       86.31         7  30.2085  634.3785   2/8/2019
#
#     TIME      PAYMENT    COGS  GROSS MARGIN PERCENTAGE  GROSS INCOME  RATING
# 0  13:08      EWALLET  522.83                 4.761905       26.1415     9.1
# ...

# %%
df.loc[50:60,['TIME','TOTAL','PAYMENT']]
# Out:
#      TIME     TOTAL      PAYMENT
# 50  10:19  671.7900         CASH
# 51  15:10  234.0975         CASH
# 52  14:42   75.0540      EWALLET
# 53  15:46   16.2015  CREDIT CARD
# 54  11:49   33.9360      EWALLET
# 55  19:01  722.2320         CASH
# 56  11:26   93.1140         CASH
# 57  11:28  752.6400      EWALLET
# 58  15:55  759.6750         CASH
# 59  20:36  192.8430         CASH
# 60  17:47   77.9310  CREDIT CARD

# %%
df.iloc[50:60,[1,2,3,4,5,6,10]]
# Out:
#    BRANCH       CITY CUSTOMER TYPE  GENDER            PRODUCT LINE  \
# 50      C  NAYPYITAW        MEMBER    MALE      FOOD AND BEVERAGES
# 51      A     YANGON        MEMBER  FEMALE      FOOD AND BEVERAGES
# 52      B   MANDALAY        MEMBER  FEMALE     FASHION ACCESSORIES
# 53      C  NAYPYITAW        MEMBER    MALE     FASHION ACCESSORIES
# 54      B   MANDALAY        NORMAL    MALE      HOME AND LIFESTYLE
# 55      C  NAYPYITAW        NORMAL  FEMALE  ELECTRONIC ACCESSORIES
# 56      A     YANGON        MEMBER    MALE      HOME AND LIFESTYLE
# 57      A     YANGON        NORMAL    MALE       HEALTH AND BEAUTY
# 58      A     YANGON        MEMBER  FEMALE      HOME AND LIFESTYLE
# 59      C  NAYPYITAW        NORMAL    MALE  ELECTRONIC ACCESSORIES
#
#     UNIT PRICE       DATE
# 50       91.40   2/3/2019
# 51       44.59  2/10/2019
# 52       17.87  3/22/2019
# 53       15.43  1/25/2019
# 54       16.16   3/7/2019
# 55       85.98  2/28/2019
# 56       44.34  3/27/2019
# ...

# %% [markdown]
# - **Réjoindre la communauté openclass4all** 👇
#  - https://www.youtube.com/channel/UCE-613S-bsuLukwHDhnRxIA/?sub_confirmation=1
#
# - **Vidéo associée à ce notebook** 👇
#  - https://youtu.be/PVSwpnLsFDM
#
# - **Merci d'ajouter une étoile à mon profil github si vous pensez que le travail que je fais est utile**.
